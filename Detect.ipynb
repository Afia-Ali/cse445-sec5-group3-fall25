# %%
# !pip install ultralytics --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.8 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
from google.colab import drive
from google.colab.patches import cv2_imshow

drive.mount('/content/drive')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Mounted at /content/drive

# %%
model = YOLO('yolov8n.pt')

image_path = '/content/drive/MyDrive/New folder/road1.jpg'

results = model(image_path)
# Out:
# ...
#
# image 1/1 /content/drive/MyDrive/New folder/road1.jpg: 448x640 4 cars, 1 train, 432.4ms
# Speed: 17.2ms preprocess, 432.4ms inference, 44.0ms postprocess per image at shape (1, 3, 448, 640)

# %%
# YOLO detected image
img_detected = results[0].plot()

# Convert BGR → RGB so plt.imshow works
img_rgb = cv2.cvtColor(img_detected, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10,10))
plt.imshow(img_rgb)
plt.axis('off')
plt.title("Final Result")
plt.show()

# %%
# !git clone https://github.com/Afia-Ali/cse445-sec5-group3-fall25.git
# %cd cse445-sec5-group3-fall25

# !git checkout rachona
# Out:
# Cloning into 'cse445-sec5-group3-fall25'...
# remote: Enumerating objects: 188, done.
# remote: Counting objects: 100% (188/188), done.
# remote: Compressing objects: 100% (183/183), done.
# remote: Total 188 (delta 9), reused 177 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (188/188), 11.50 MiB | 27.45 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/cse445-sec5-group3-fall25
# Branch 'rachona' set up to track remote branch 'rachona' from 'origin'.
# Switched to a new branch 'rachona'

# %%
# !cp "/content/drive/MyDrive/New folder/road1.jpg" .

# %%
# !git config --global user.email "ahmed.rachona@northsouth.edu"
# !git config --global user.name "SinthiaAhmedRachona"

# !git add .
# !git commit -m "Added my detection project files"
# Out:
# [rachona 2d50175] Added my detection project files
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 road1.jpg
